# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
movies.head(1)

# %%
credits.head(1)

# %%
movies = movies.merge(credits, on = "title")

# %%
movies.shape

# %%
movies.head(1)

# %% [markdown]
# ## Important columns

# %%
# genre id keyword title overview cast crew
movies = movies[["movie_id", "title", "overview", "genres", "keywords", "crew"]]

# %%
movies.info()

# %%
movies.head()
